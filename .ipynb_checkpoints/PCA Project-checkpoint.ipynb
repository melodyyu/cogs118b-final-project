# %%
import numpy as np
import pandas as pd
import scipy.io as sio
import matplotlib
import matplotlib.pyplot as plt
from numpy.matlib import repmat
from sklearn.preprocessing import normalize

# %matplotlib inline

# %%
def eigsort(V, eigvals):
    
    # Sort the eigenvalues from largest to smallest. Store the sorted
    # eigenvalues in the column vector lambd.
    lohival = np.sort(eigvals)
    lohiindex = np.argsort(eigvals)
    lambd = np.flip(lohival)
    index = np.flip(lohiindex)
    Dsort = np.diag(lambd)
    
    # Sort eigenvectors to correspond to the ordered eigenvalues. Store sorted
    # eigenvectors as columns of the matrix vsort.
    M = np.size(lambd)
    Vsort = np.zeros((M, M))
    for i in range(M):
        Vsort[:,i] = V[:,index[i]]
    return Vsort, Dsort

# %%
df = pd.read_csv("encoded_smartphone_data.csv")

# %%
df
# Out:
#        Unnamed: 0     Brand  \
# 0               0       ZTE
# 1               1   Samsung
# 2               2        LG
# 3               3    Huawei
# 4               4     Nokia
# ...           ...       ...
# 13564       13938   Samsung
# 13565       13939  Vodafone
# 13566       13940     E-TEN
# 13567       13941     Airis
# 13568       13942     Nokia
#
#                                                    Model            Added  \
# 0                     Blade 20 Smart Global TD-LTE 128GB   1/1/2020 12:55
# 1           SM-G6200 Galaxy A6s Dual SIM TD-LTE CN 128GB  11/7/2018 22:32
# 2               LMV450VMB V50 ThinQ 5G TD-LTE US V450VMB   3/5/2019 23:31
# 3      Y5 Lite 2018 Dual SIM LTE LATAM CAG-LX3 / CAG-L23  5/10/2018 20:11
# 4                            4.2 Dual SIM TD-LTE AM 32GB  8/14/2019 15:07
# ...                                                  ...              ...
# 13564                                           SGH-i780  9/22/2007 23:57
# ...

# %%
df.isnull().any().any()
# Out:
# False

# %%
try_mean = df.mean() #gets mean of every numerical column
try_mean.shape
# try_mean
# Out:
# (150,)

# %%
try_sample_mean = np.mean(df, axis=1)
try_sample_mean.shape
# try_sample_mean
# Out:
# (13569,)

# %%
# sample_mean = np.mean(df[4,:], axis = 1)
# sample_mean.shapeb
# sample_mean
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-c73f52d5a944> in <module>
# ----> 1 sample_mean = np.mean(df[4,:], axis = 1)
#       2 # sample_mean.shape
#       3 # sample_mean
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# ...

# %%
try_sample_mean = try_sample_mean.T
try_sample_mean.shape
try_sample_mean
# Out:
# 0         746.444458
# 1         671.463867
# 2         672.260640
# 3         675.455477
# 4         595.830484
#             ...
# 13564     705.335620
# 13565     865.357600
# 13566    1476.719467
# 13567     817.760000
# 13568    1073.046000
# Length: 13569, dtype: float64

# %%
df_series = pd.Series(try_sample_mean)
df_series
df_series.shape
# Out:
# (13569,)

# %%
reshape_mean = pd.DataFrame(df_series)
reshape_mean.shape
reshape_mean
# Out:
#                  0
# 0       746.444458
# 1       671.463867
# 2       672.260640
# 3       675.455477
# 4       595.830484
# ...            ...
# 13564   705.335620
# 13565   865.357600
# 13566  1476.719467
# 13567   817.760000
# 13568  1073.046000
#
# [13569 rows x 1 columns]

# %%
try_reshape_mean = np.reshape(df_series, (13569, -1))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-112-1cc185277c56> in <module>
# ----> 1 try_reshape_mean = np.reshape(df_series, (13569, -1))
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      53     bound = getattr(obj, method, None)
#      54     if bound is None:
# ---> 55         return _wrapit(obj, method, *args, **kwds)
#      56
#      57     try:
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
# ...

# %%
len(df_series)
# Out:
# 13569
